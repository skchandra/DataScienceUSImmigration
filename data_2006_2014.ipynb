# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_2006 = pd.read_table('2006.tsv')
df_2007 = pd.read_table('2007.tsv')
df_2008 = pd.read_table('2008.tsv')
df_2009 = pd.read_table('2009.csv')
df_2010 = pd.read_table('2010.csv')
df_2011 = pd.read_table('2011.csv')
df_2012 = pd.read_table('2012.csv')
df_2013 = pd.read_table('2013.tsv')
df_2014 = pd.read_table('2014.csv')
df_2009
# Out:
#                                               Subject      Asia   Europe  \
# 0                             Foreign-born population  10652379  4887221
# 1                     CITIZENSHIP AND PERIOD OF ENTRY       NaN      NaN
# 2                                 Naturalized citizen    58.10%   61.40%
# 3                               Entered 2000 or later     5.50%    4.00%
# 4                                Entered 1990 to 1999    17.50%   15.20%
# 5                                 Entered before 1990    35.20%   42.20%
# 6                                                 NaN       NaN      NaN
# 7                                       Not a citizen    41.90%   38.60%
# 8                               Entered 2000 or later    27.40%   18.20%
# 9                                Entered 1990 to 1999     9.30%    9.60%
# 10                                Entered before 1990     5.10%   10.80%
# 11                                                NaN       NaN      NaN
# ...

# %%
def clean(x):
    try:
        if '%' in x:
            return float(x.strip('%'))   
        elif ',' in x:
            return float(x.replace(',',''))
        else:
            return float(x)
    except:
        return float(x)

# %%
df_2008.head()
# Out:
#                            Subject        Asia     Europe Latin America  \
# 0          Foreign-born population  10,355,577  4,969,090    20,150,245
# 1  CITIZENSHIP AND PERIOD OF ENTRY         NaN        NaN           NaN
# 2              Naturalized citizen      57.50%     60.30%        31.40%
# 3            Entered 2000 or later       4.30%      3.30%         2.00%
# 4             Entered 1990 to 1999      17.10%     14.50%         6.60%
#
#       Africa Northern American  Oceania       Total
# 0  1,435,996           826,871  222,994  37,960,935
# 1        NaN               NaN      NaN         NaN
# 2     42.80%            44.70%   34.00%      43.00%
# 3      6.80%             1.60%    3.40%       3.00%
# 4     16.50%             6.70%    8.40%      10.90%

# %%
#unemployment
num = 33

unemployment_asia = [df_2006['Asia'].iloc[num],df_2007['Asia'].iloc[num],df_2008['Asia'].iloc[num],df_2009['Asia'].iloc[num],df_2010['Asia'].iloc[num],df_2011['Asia'].iloc[num],df_2012['Asia'].iloc[num],df_2013['Asia'].iloc[num],df_2014['Asia'].iloc[num]]
unemployment_europe = [df_2006['Europe'].iloc[num],df_2007['Europe'].iloc[num],df_2008['Europe'].iloc[num],df_2009['Europe'].iloc[num],df_2010['Europe'].iloc[num],df_2011['Europe'].iloc[num],df_2012['Europe'].iloc[num],df_2013['Europe'].iloc[num],df_2014['Europe'].iloc[num]]
unemployment_latin_america = [df_2006['Latin America'].iloc[num],df_2007['Latin America'].iloc[num],df_2008['Latin America'].iloc[num],df_2009['Latin America'].iloc[num],df_2010['Latin America'].iloc[num],df_2011['Latin America'].iloc[num],df_2012['Latin America'].iloc[num],df_2013['Latin America'].iloc[num],df_2014['Latin America'].iloc[num]]
unemployment_africa = [df_2006['Africa'].iloc[num],df_2007['Africa'].iloc[num],df_2008['Africa'].iloc[num],df_2009['Africa'].iloc[num],df_2010['Africa'].iloc[num],df_2011['Africa'].iloc[num],df_2012['Africa'].iloc[num],df_2013['Africa'].iloc[num],df_2014['Africa'].iloc[num]]
unemployment_northern_america = [df_2006['Northern America'].iloc[num],df_2007['Northern America'].iloc[num],df_2008['Northern American'].iloc[num],df_2009['Northern America'].iloc[num],df_2010['Northern America'].iloc[num],df_2011['Northern America'].iloc[num],df_2012['Northern America'].iloc[num],df_2013['Northern America'].iloc[num],df_2014['Northern America'].iloc[num]]
unemployment_oceania = [df_2006['Oceania'].iloc[num],df_2007['Oceania'].iloc[num],df_2008['Oceania'].iloc[num],df_2009['Oceania'].iloc[num],df_2010['Oceania'].iloc[num],df_2011['Oceania'].iloc[num],df_2012['Oceania'].iloc[num],df_2013['Oceania'].iloc[num],df_2014['Oceania'].iloc[num]]

unemployment_asia = [clean(x) for x in unemployment_asia]
unemployment_europe = [clean(x) for x in unemployment_europe]
unemployment_latin_america = [clean(x) for x in unemployment_latin_america]
unemployment_africa = [clean(x) for x in unemployment_africa]
unemployment_northern_america = [clean(x) for x in unemployment_northern_america]
unemployment_oceania = [clean(x) for x in unemployment_oceania]

# %%
def line_plot(data,title,xlabel,ylabel,xticks,legend):
    plt.figure(figsize=(15,11))
    xvals = 0
    p = {}
    for i,val in enumerate(data):
        xvals = np.arange(len(val))
        p[i] = plt.plot(np.arange(len(val)),val)
    plt.title(title,fontsize=16)
    plt.xlabel(xlabel,fontsize=16)
    plt.ylabel(ylabel,fontsize=16)
    plt.xticks(xvals,xticks,fontsize=12)
    legend1 = [p[i][0] for i in p]
    plt.legend(legend1,legend,fontsize=12)
    
    import matplotlib.ticker as tkr
    formatter = tkr.ScalarFormatter(useMathText=False)
    formatter.set_scientific(False)
    
    plt.show()

# %%
#plot unemployment rate over time

xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Unemployment Rate from 2006-2014'
ylabel = 'Percentage of Group\'s Workforce'
xlabel = 'Years'

line_plot([unemployment_asia,unemployment_europe,unemployment_latin_america,unemployment_africa,unemployment_northern_america,unemployment_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 0

pop_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
pop_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
pop_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
pop_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
pop_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
pop_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

pop_asia = [clean(x) for x in pop_asia]
pop_europe = [clean(x) for x in pop_europe]
pop_latin_america = [clean(x) for x in pop_latin_america]
pop_africa = [clean(x) for x in pop_africa]
pop_northern_america = [clean(x) for x in pop_northern_america]
pop_oceania = [clean(x) for x in pop_oceania]

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Amount of Immigrants in US from 2006-2014'
ylabel = 'Number of People'
xlabel = 'Years'

line_plot([pop_asia,pop_europe,pop_latin_america,pop_africa,pop_northern_america,pop_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 2

nat_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
nat_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
nat_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
nat_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
nat_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
nat_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

nat_asia = [clean(x) for x in nat_asia]
nat_europe = [clean(x) for x in nat_europe]
nat_latin_america = [clean(x) for x in nat_latin_america]
nat_africa = [clean(x) for x in nat_africa]
nat_northern_america = [clean(x) for x in nat_northern_america]
nat_oceania = [clean(x) for x in nat_oceania]

print df_2006['Subject'].iloc[2]
print df_2006['Asia'].iloc[2]
# Out:
# Naturalized citizen
# 56.70%

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Amount of Naturalized Immigrants in US from 2006-2014'
ylabel = 'Percent of Immigrants'
xlabel = 'Years'

line_plot([nat_asia,nat_europe,nat_latin_america,nat_africa,nat_northern_america,nat_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 46

low_income_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
low_income_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
low_income_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
low_income_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
low_income_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
low_income_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

low_income_asia = [clean(x) for x in low_income_asia]
low_income_europe = [clean(x) for x in low_income_europe]
low_income_latin_america = [clean(x) for x in low_income_latin_america]
low_income_africa = [clean(x) for x in low_income_africa]
low_income_northern_america = [clean(x) for x in low_income_northern_america]
low_income_oceania = [clean(x) for x in low_income_oceania]

print df_2006['Subject'].iloc[46]
print df_2006['Asia'].iloc[46]
# Out:
# $1 to $9,999 or loss
# 2.20%

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Amount of Immigrants in Lowest Income Bracket from 2006-2014'
ylabel = 'Percent of Earners over 16'
xlabel = 'Years'

line_plot([low_income_asia,low_income_europe,low_income_latin_america,low_income_africa,low_income_northern_america,low_income_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 52

high_income_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
high_income_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
high_income_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
high_income_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
high_income_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
high_income_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

high_income_asia = [clean(x) for x in high_income_asia]
high_income_europe = [clean(x) for x in high_income_europe]
high_income_latin_america = [clean(x) for x in high_income_latin_america]
high_income_africa = [clean(x) for x in high_income_africa]
high_income_northern_america = [clean(x) for x in high_income_northern_america]
high_income_oceania = [clean(x) for x in high_income_oceania]

print df_2006['Subject'].iloc[52]
print df_2006['Asia'].iloc[52]
# Out:
# $75,000 or more
# 24.20%

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Amount of Immigrants in Highest Income Bracket from 2006-2014'
ylabel = 'Percent of Earners over 16'
xlabel = 'Years'

line_plot([high_income_asia,high_income_europe,high_income_latin_america,high_income_africa,high_income_northern_america,high_income_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 56

below_poverty_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
below_poverty_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
below_poverty_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
below_poverty_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
below_poverty_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
below_poverty_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

below_poverty_asia = [clean(x) for x in below_poverty_asia]
below_poverty_europe = [clean(x) for x in below_poverty_europe]
below_poverty_latin_america = [clean(x) for x in below_poverty_latin_america]
below_poverty_africa = [clean(x) for x in below_poverty_africa]
below_poverty_northern_america = [clean(x) for x in below_poverty_northern_america]
below_poverty_oceania = [clean(x) for x in below_poverty_oceania]

print df_2006['Subject'].iloc[56]
print df_2006['Asia'].iloc[56]
# Out:
# Below 100 percent of the poverty level
# 11.70%

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Amount of Immigrants Below 100 Percent of Poverty Level from 2006-2014'
ylabel = 'Percent of Earners over 16'
xlabel = 'Years'

line_plot([below_poverty_asia,below_poverty_europe,below_poverty_latin_america,below_poverty_africa,below_poverty_northern_america,below_poverty_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 63

renters_perc_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
renters_perc_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
renters_perc_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
renters_perc_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
renters_perc_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
renters_perc_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

renters_perc_asia = [clean(x) for x in renters_perc_asia]
renters_perc_europe = [clean(x) for x in renters_perc_europe]
renters_perc_latin_america = [clean(x) for x in renters_perc_latin_america]
renters_perc_africa = [clean(x) for x in renters_perc_africa]
renters_perc_northern_america = [clean(x) for x in renters_perc_northern_america]
renters_perc_oceania = [clean(x) for x in renters_perc_oceania]

print df_2006['Subject'].iloc[63]
print df_2006['Asia'].iloc[63]
# Out:
# Renter-occupied housing units
# 41.00%

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Amount of Immigrants Who Rent from 2006-2014'
ylabel = 'Percent'
xlabel = 'Years'

line_plot([renters_perc_asia,renters_perc_europe,renters_perc_latin_america,renters_perc_africa,renters_perc_northern_america,renters_perc_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 62

owner_perc_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
owner_perc_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
owner_perc_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
owner_perc_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
owner_perc_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
owner_perc_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

owner_perc_asia = [clean(x) for x in owner_perc_asia]
owner_perc_europe = [clean(x) for x in owner_perc_europe]
owner_perc_latin_america = [clean(x) for x in owner_perc_latin_america]
owner_perc_africa = [clean(x) for x in owner_perc_africa]
owner_perc_northern_america = [clean(x) for x in owner_perc_northern_america]
owner_perc_oceania = [clean(x) for x in owner_perc_oceania]

print df_2006['Subject'].iloc[62]
print df_2006['Asia'].iloc[62]
# Out:
# Owner-occupied housing units
# 59.00%

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Amount of Immigrants Who Own Housing Units from 2006-2014'
ylabel = 'Percent'
xlabel = 'Years'

line_plot([owner_perc_asia,owner_perc_europe,owner_perc_latin_america,owner_perc_africa,owner_perc_northern_america,owner_perc_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 69

ling_isolated_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
ling_isolated_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
ling_isolated_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
ling_isolated_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
ling_isolated_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
ling_isolated_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

ling_isolated_asia = [clean(x) for x in ling_isolated_asia]
ling_isolated_europe = [clean(x) for x in ling_isolated_europe]
ling_isolated_latin_america = [clean(x) for x in ling_isolated_latin_america]
ling_isolated_africa = [clean(x) for x in ling_isolated_africa]
ling_isolated_northern_america = [clean(x) for x in ling_isolated_northern_america]
ling_isolated_oceania = [clean(x) for x in ling_isolated_oceania]

print df_2006['Subject'].iloc[69]
print df_2006['Asia'].iloc[69]
# Out:
# Linguistically isolated households
# 27.20%

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Amount of Linguistically Isolated Households from 2006-2014'
ylabel = 'Percent'
xlabel = 'Years'

line_plot([ling_isolated_asia,ling_isolated_europe,ling_isolated_latin_america,ling_isolated_africa,ling_isolated_northern_america,ling_isolated_oceania],title,xlabel,ylabel,xticks,legend)

# %%
#total population in that year
row = 35

not_labor_force_asia = [df_2006['Asia'].iloc[row],df_2007['Asia'].iloc[row],df_2008['Asia'].iloc[row],df_2009['Asia'].iloc[row],df_2010['Asia'].iloc[row],df_2011['Asia'].iloc[row],df_2012['Asia'].iloc[row],df_2013['Asia'].iloc[row],df_2014['Asia'].iloc[row]]
not_labor_force_europe = [df_2006['Europe'].iloc[row],df_2007['Europe'].iloc[row],df_2008['Europe'].iloc[row],df_2009['Europe'].iloc[row],df_2010['Europe'].iloc[row],df_2011['Europe'].iloc[row],df_2012['Europe'].iloc[row],df_2013['Europe'].iloc[row],df_2014['Europe'].iloc[row]]
not_labor_force_latin_america = [df_2006['Latin America'].iloc[row],df_2007['Latin America'].iloc[row],df_2008['Latin America'].iloc[row],df_2009['Latin America'].iloc[row],df_2010['Latin America'].iloc[row],df_2011['Latin America'].iloc[row],df_2012['Latin America'].iloc[row],df_2013['Latin America'].iloc[row],df_2014['Latin America'].iloc[row]]
not_labor_force_africa = [df_2006['Africa'].iloc[row],df_2007['Africa'].iloc[row],df_2008['Africa'].iloc[row],df_2009['Africa'].iloc[row],df_2010['Africa'].iloc[row],df_2011['Africa'].iloc[row],df_2012['Africa'].iloc[row],df_2013['Africa'].iloc[row],df_2014['Africa'].iloc[row]]
not_labor_force_northern_america = [df_2006['Northern America'].iloc[row],df_2007['Northern America'].iloc[row],df_2008['Northern America'].iloc[row],df_2009['Northern America'].iloc[row],df_2010['Northern America'].iloc[row],df_2011['Northern America'].iloc[row],df_2012['Northern America'].iloc[row],df_2013['Northern America'].iloc[row],df_2014['Northern America'].iloc[row]]
not_labor_force_oceania = [df_2006['Oceania'].iloc[row],df_2007['Oceania'].iloc[row],df_2008['Oceania'].iloc[row],df_2009['Oceania'].iloc[row],df_2010['Oceania'].iloc[row],df_2011['Oceania'].iloc[row],df_2012['Oceania'].iloc[row],df_2013['Oceania'].iloc[row],df_2014['Oceania'].iloc[row]]

not_labor_force_asia = [clean(x) for x in not_labor_force_asia]
not_labor_force_europe = [clean(x) for x in not_labor_force_europe]
not_labor_force_latin_america = [clean(x) for x in not_labor_force_latin_america]
not_labor_force_africa = [clean(x) for x in not_labor_force_africa]
not_labor_force_northern_america = [clean(x) for x in not_labor_force_northern_america]
not_labor_force_oceania = [clean(x) for x in not_labor_force_oceania]

print df_2006['Subject'].iloc[35]
print df_2006['Asia'].iloc[35]
# Out:
# Not in labor force
# 34.20%

# %%
xticks = ('2006','2007','2008','2009','2010','2011','2012','2013','2014')
legend = ('Asia','Europe','Latin America','Africa','Northern America','Oceania')
title= 'Percentage of Immigrants over 16 not in Labor Force from 2006-2014'
ylabel = 'Percent'
xlabel = 'Years'

line_plot([not_labor_force_asia,not_labor_force_europe,not_labor_force_latin_america,not_labor_force_africa,not_labor_force_northern_america,not_labor_force_oceania],title,xlabel,ylabel,xticks,legend)
