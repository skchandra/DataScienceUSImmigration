# %% [markdown]
# In this data set, we will explore education for immigrants of all countries.

# %%
import pandas 
import numpy
import matplotlib.pyplot as plt
import importingData

# %matplotlib inline
# Out:
# /home/casey/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
def make_piBar(things2Plot, labels, title): 
    labels = labels
    sizes = things2Plot
    colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
    patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
    plt.legend(patches, labels, loc="best")
    plt.axis('equal')
    plt.tight_layout()
    plt.title(title)
    plt.show()

# %%
def many_bars(x, y1, y2, y3, y4, y5, title, xlabels): 
    x_decreased_by_01 = [y - 0.1 for y in x]
    x_decreased_by_02 = [y - 0.2 for y in x]
    x_increased_by_01 = [y + 0.1 for y in x]
    x_increased_by_02 = [y + 0.2 for y in x]
    print y1 
    print y2 
    print y3
    print y4 
    print y5
    ax = plt.subplot(111)
    bar1 = ax.bar(x_decreased_by_02, y1,width=0.1,color='b',align='center', label = 'less than hs')
    bar2 = ax.bar(x_decreased_by_01, y2,width=0.1,color='g',align='center', label = 'high school')
    bar3 = ax.bar(x, y3,width=0.1,color='r',align='center', label = 'some college')
    bar4 = ax.bar(x_increased_by_01, y4,width=0.1,color='c',align='center', label = 'bachelors degree')
    bar5 = ax.bar(x_increased_by_02, y5,width=0.1,color='y',align='center', label = 'graduate school')
    
    plt.legend(handles=[bar2, bar3, bar4])
    plt.title(title)
    plt.xticks(x, xlabels)
    plt.show()

# %%
def many_bars_1_x(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5, title, xlabels, labels): 
    x_decreased_by_01 = [y - 0.1 for y in x]
    x_increased_by_01 = [y + 0.1 for y in x]
    print y1 
    
    plt.figure(figsize=(15,10))
    ax1 = plt.subplot(1, 5, 1)
#     ax1 = plt.subplot(111)
    bar1 = ax1.bar(x1, y1,width=0.1,color='b',align='center', label = labels[0])
    
    plt.legend(handles=[bar1])
    plt.title(title)
    plt.xticks(x1, xlabels)
    plt.ylim([0, 450000])
    
    ax2 = plt.subplot(1, 5, 2)
    bar2 = ax2.bar(x2, y2,width=0.1,color='b',align='center', label = labels[1])
    
    plt.legend(handles=[bar2])
#     plt.title(title)
    plt.xticks(x2, xlabels)
    plt.ylim([0, 450000])
    
    
    ax3 = plt.subplot(1, 5, 3)
    bar3 = ax3.bar(x3, y3, width=0.1,color='b',align='center', label = labels[2])
    plt.legend(handles=[bar3])
#     plt.title(title)
    plt.xticks(x3, xlabels)
    plt.ylim([0, 450000])
    
    ax4 = plt.subplot(1, 5, 4)
    bar4 = ax4.bar(x4, y4, width=0.1,color='b',align='center', label = labels[3])
    plt.legend(handles=[bar4])
#     plt.title(title)
    plt.xticks(x4, xlabels)
    plt.ylim([0, 450000])
    
    ax5 = plt.subplot(1, 5, 5)
    bar5 = ax5.bar(x5, y5, width=0.1,color='b',align='center', label = labels[4])
    plt.legend(handles=[bar5])
#     plt.title(title)
    plt.xticks(x5, xlabels)
    plt.ylim([0, 450000])
    
    
    
    plt.show()


#     plt.subplot(1, 2, 1)
#     plt.plot(x1, y1, 'ko-')
#     plt.title('A tale of 2 subplots')
#     plt.ylabel('Damped oscillation')

#     plt.subplot(1, 2, 2)
#     plt.plot(x2, y2, 'r.-')
#     plt.xlabel('time (s)')
#     plt.ylabel('Undamped')

#     plt.show()

# %%
def many_bars2(x, y1, title, xlabels): 
#     x_decreased_by_01 = [y - 0.1 for y in x]
#     x_decreased_by_02 = [y - 0.2 for y in x]
#     x_increased_by_01 = [y + 0.1 for y in x]
#     x_increased_by_02 = [y + 0.2 for y in x]
    
    ax = plt.subplot(111)
    bar1 = ax.bar(x + 0.1, [10],width=0.1,color='b',align='center', label = 'less than hs')
    bar2 = ax.bar(x - 0.1, [15],width=0.1,color='y',align='center', label = 'less than hs')
    bar3 = ax.bar(x, [10],width=0.1,color='g',align='center', label = 'less than hs')
    
    plt.legend(handles=[bar1])
    plt.title(title)
    plt.xticks(x, xlabels)
    plt.show()

# %% [raw]
# Downloading information for African, Northern American and Oceania regions.

# %%
africa_northamerica_and_oceania_14 = importingData.African_NorthernAmerica_and_OceaniaData()
df_africa_northamerica_and_oceania_14 = africa_northamerica_and_oceania_14.african_northernamerica_and_oceania_data_2014

# %%
enrolled_in_school_total = africa_northamerica_and_oceania_14.enrolled_in_school_total()
make_piBar(enrolled_in_school_total[1:len(enrolled_in_school_total)],  labels = ['Nursery School', 'Elementary School', 'High School', 'College'], 
          title = "Africans, Northern Americans, and Oceania in 2014 enrolled in school. Total in School is" + enrolled_in_school_total[0])

# %%
enrolled_in_school_total_born_in_Africa = africa_northamerica_and_oceania_14.enrolled_in_school_born_in_Africa()
make_piBar(enrolled_in_school_total_born_in_Africa[1:len(enrolled_in_school_total_born_in_Africa)],  labels = ['Nursery School', 'Elementary School', 'High School', 'College'], 
          title = "Africans in 2014 enrolled in school. Total enrolled in School is" + enrolled_in_school_total_born_in_Africa[0])

# %%
enrolled_in_school_total_Northern_America = africa_northamerica_and_oceania_14.enrolled_in_school_born_in_Northern_America()
make_piBar(enrolled_in_school_total_Northern_America[1:len(enrolled_in_school_total_Northern_America)],  labels = ['Nursery School', 'Elementary School', 'High School', 'College'], 
          title = "Northern Americans in 2014 enrolled in school. Total enrolled in School is" + enrolled_in_school_total_Northern_America[0])

# %%
enrolled_in_school_total_Oceania = africa_northamerica_and_oceania_14.enrolled_in_school_born_in_Oceania()
make_piBar(enrolled_in_school_total_Oceania[1:len(enrolled_in_school_total_Oceania)],  labels = ['Nursery School', 'Elementary School', 'High School', 'College'], 
          title = "People from Oceania in 2014 enrolled in school, total count: " + enrolled_in_school_total_Oceania[0])

# %%
y = africa_northamerica_and_oceania_14.less_than_hs_grad_fraction_of_whole()
k = africa_northamerica_and_oceania_14.hs_grad_fraction_of_whole()
z = africa_northamerica_and_oceania_14.some_college_fraction_of_whole()
x = africa_northamerica_and_oceania_14.bachelors_degree_fraction_of_whole()
t = africa_northamerica_and_oceania_14.graduate_degree_fraction_of_whole()
print y
print k 
print z 
print x 
print t
# Out:
# printing totals total, africa, na, and oceania 367455 15698 7267 2006
# less than hs grad total, born in africa, born in northern america, and born in oceania 29.9 12.1 8.7 13.9
# floats [189945.8, 63222.899999999994, 27883.4]
#  hs grad total, africa, northern america, and oceania 22.7 19.9 18.9 26.2
# some college born in africa, northern america, and oceania 27.8 28.0 27.9
# grad degree for all 16.6 19.7 12.5
# [189945.8, 63222.899999999994, 27883.4]
# [312390.19999999995, 137346.3, 52557.2]
# [436404.4, 203476.0, 55967.399999999994]
# [370472.80000000005, 178768.2, 39317.600000000006]
# [260586.80000000002, 143159.9, 25075.0]

# %%
# less than hs grad
x = [0, 1, 2]
many_bars_1_x(x, x, x, x, x, y, k, z, x, t, 'Less than high school education attainment of Africans, Northern Americans, and Oceanics', 
          ['Africans', 'N. Americans', 'Oceanics'], 'less than high school education')
# Out:
# [189945.8, 63222.899999999994, 27883.4]

# %%
#hs graduate 
many_bars_1_x([0, 1, 2], k, 'High school graduate education of Africans, Northern Americans, and Oceanics', 
          ['Africans', 'N. Americans', 'Oceanics'], ' at least a high school education')
# Out:
# [312390.19999999995, 137346.3, 52557.2]

# %%
#some college 
many_bars_1_x([0, 1, 2], z, 'Some college education of Africans, Northern Americans, and Oceanics', 
          ['Africans', 'N. Americans', 'Oceanics'], 'some college education')
# Out:
# [436404.4, 203476.0, 55967.399999999994]

# %%
many_bars_1_x([0, 1, 2], x, 'Bachelors degree of Africans, Northern Americans, and Oceanics', 
          ['Africans', 'N. Americans', 'Oceanics'], 'bachelors degree')
# Out:
# [370472.80000000005, 178768.2, 39317.600000000006]

# %%
many_bars_1_x([0, 1, 2], t, 'Graduate degree of Africans, Northern Americans, and Oceanics', 
          ['Africans', 'N. Americans', 'Oceanics'], 'graduate degree')
# Out:
# [260586.80000000002, 143159.9, 25075.0]

# %%
africa_education = africa_northamerica_and_oceania_14.educ_attainment_born_in_Africa()
northern_america_education = africa_northamerica_and_oceania_14.educ_attainment_born_in_Northern_America()
oceania_education = africa_northamerica_and_oceania_14.educ_attainment_born_in_Oceania()
print africa_education 
print northern_america_education
print oceania_education

# %%
many_bars([0, 1, 2, 3, 4], africa_education, northern_america_education, oceania_education, 
          'Educational Obtainment of Africans, Northern Americans, and Oceanics', 
          ['Born in Africa', 'Born in Northern America', 'Born in Oceania'])
