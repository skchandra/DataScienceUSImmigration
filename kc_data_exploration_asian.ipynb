# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /home/kiki/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/kiki/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
df = pd.read_csv('asia_acs_foreign_born_characteristics_14.csv')
df
# Out:
#       GEO.id GEO.id2 GEO.display-label  \
# 0         Id     Id2         Geography
# 1  0100000US     NaN     United States
#
#                               HC01_EST_VC01  \
# 0  Total; Estimate; Foreign-born population
# 1                                  42391794
#
#                                      HC01_MOE_VC01  \
# 0  Total; Margin of Error; Foreign-born population
# 1                                           130122
#
#                                        HC02_EST_VC01  \
# 0  Foreign born; Born in Asia; Estimate; Foreign-...
# 1                                           12750422
#
#                                        HC02_MOE_VC01  \
# 0  Foreign born; Born in Asia; Margin of Error; F...
# 1                                              47011
#
#                                        HC03_EST_VC01  \
# 0  Foreign born; Born in Eastern Asia; Estimate; ...
# 1                                            3950698
#
# ...

# %%
#print df['HC01_EST_VC78'].loc[0]
tot_pop_16 = float(df['HC01_EST_VC78'].loc[1])
#print df['HC02_EST_VC78'].loc[0]
asian_tot_pop_16 = float(df['HC02_EST_VC78'].loc[1])
#print df['HC03_EST_VC78'].loc[0]
east_pop_16 = float(df['HC03_EST_VC78'].loc[1])
#print df['HC04_EST_VC78'].loc[0]
south_central_pop_16 = float(df['HC04_EST_VC78'].loc[1])
#print df['HC05_EST_VC78'].loc[0]
south_east_pop_16 = float(df['HC05_EST_VC78'].loc[1])
#print df['HC06_EST_VC78'].loc[0]
west_pop_16 = float(df['HC06_EST_VC78'].loc[1])

#print df['HC01_EST_VC79'].loc[0]
tot_labor_perc = float(df['HC01_EST_VC79'].loc[1])
#print df['HC02_EST_VC79'].loc[0]
asian_tot_labor_perc = float(df['HC02_EST_VC79'].loc[1])
#print df['HC03_EST_VC79'].loc[0]
east_labor_perc = float(df['HC03_EST_VC79'].loc[1])
#print df['HC04_EST_VC79'].loc[0]
south_central_labor_perc = float(df['HC04_EST_VC79'].loc[1])
#print df['HC05_EST_VC79'].loc[0]
south_east_labor_perc = float(df['HC05_EST_VC79'].loc[1])
#print df['HC06_EST_VC79'].loc[0]
west_labor_perc = float(df['HC06_EST_VC79'].loc[1])

#print df['HC01_EST_VC80'].loc[0]
tot_civ_labor_perc = float(df['HC01_EST_VC80'].loc[1])
#print df['HC02_EST_VC80'].loc[0]
asian_tot_civ_labor_perc = float(df['HC02_EST_VC80'].loc[1])
#print df['HC03_EST_VC80'].loc[0]
east_civ_labor_perc = float(df['HC03_EST_VC80'].loc[1])
#print df['HC04_EST_VC80'].loc[0]
south_central_civ_labor_perc = float(df['HC04_EST_VC80'].loc[1])
#print df['HC05_EST_VC80'].loc[0]
south_east_civ_labor_perc = float(df['HC05_EST_VC80'].loc[1])
#print df['HC06_EST_VC80'].loc[0]
west_civ_labor_perc = float(df['HC06_EST_VC80'].loc[1])

#print df['HC01_EST_VC81'].loc[0]
tot_civ_labor_emp_perc = float(df['HC01_EST_VC81'].loc[1])
#print df['HC02_EST_VC81'].loc[0]
asian_tot_civ_labor_emp_perc = float(df['HC02_EST_VC81'].loc[1])
#print df['HC03_EST_VC81'].loc[0]
east_civ_labor_emp_perc = float(df['HC03_EST_VC81'].loc[1])
#print df['HC04_EST_VC81'].loc[0]
south_central_civ_labor_emp_perc = float(df['HC04_EST_VC81'].loc[1])
#print df['HC05_EST_VC81'].loc[0]
south_east_civ_labor_emp_perc = float(df['HC05_EST_VC81'].loc[1])
#print df['HC06_EST_VC81'].loc[0]
west_civ_labor_emp_perc = float(df['HC06_EST_VC81'].loc[1])

tot_civ_labor_emp_perc_lab = tot_civ_labor_emp_perc/tot_civ_labor_perc*100
asian_tot_civ_labor_emp_perc_lab = asian_tot_civ_labor_emp_perc/asian_tot_civ_labor_perc*100
east_civ_labor_emp_perc_lab = east_civ_labor_emp_perc/east_civ_labor_perc*100
south_central_civ_labor_emp_perc_lab = south_central_civ_labor_emp_perc/south_central_civ_labor_perc*100
south_east_civ_labor_emp_perc_lab = south_east_civ_labor_emp_perc/south_east_civ_labor_perc*100
west_civ_labor_emp_perc_lab = west_civ_labor_emp_perc/west_civ_labor_perc*100

#print df['HC01_EST_VC82'].loc[0]
tot_civ_labor_unemp_perc = float(df['HC01_EST_VC82'].loc[1])
#print df['HC02_EST_VC82'].loc[0]
asian_tot_civ_labor_unemp_perc = float(df['HC02_EST_VC82'].loc[1])
#print df['HC03_EST_VC82'].loc[0]
east_civ_labor_unemp_perc = float(df['HC03_EST_VC82'].loc[1])
#print df['HC04_EST_VC82'].loc[0]
south_central_civ_labor_unemp_perc = float(df['HC04_EST_VC82'].loc[1])
#print df['HC05_EST_VC82'].loc[0]
south_east_civ_labor_unemp_perc = float(df['HC05_EST_VC82'].loc[1])
#print df['HC06_EST_VC82'].loc[0]
west_civ_labor_unemp_perc = float(df['HC06_EST_VC82'].loc[1])

#print df['HC01_EST_VC83'].loc[0]
tot_civ_labor_unemp_perc_lab = float(df['HC01_EST_VC83'].loc[1])
#print df['HC02_EST_VC83'].loc[0]
asian_tot_civ_labor_unemp_perc_lab = float(df['HC02_EST_VC83'].loc[1])
#print df['HC03_EST_VC83'].loc[0]
east_civ_labor_unemp_perc_lab = float(df['HC03_EST_VC83'].loc[1])
#print df['HC04_EST_VC83'].loc[0]
south_central_civ_labor_unemp_perc_lab = float(df['HC04_EST_VC83'].loc[1])
#print df['HC05_EST_VC83'].loc[0]
south_east_civ_labor_unemp_perc_lab = float(df['HC05_EST_VC83'].loc[1])
#print df['HC06_EST_VC83'].loc[0]
west_civ_labor_unemp_perc_lab = float(df['HC06_EST_VC83'].loc[1])

#print df['HC01_EST_VC85'].loc[0]
tot_not_labor_perc = float(df['HC01_EST_VC85'].loc[1])
#print df['HC02_EST_VC85'].loc[0]
asian_tot_not_labor_perc = float(df['HC02_EST_VC85'].loc[1])
#print df['HC03_EST_VC85'].loc[0]
east_not_labor_perc = float(df['HC03_EST_VC85'].loc[1])
#print df['HC04_EST_VC85'].loc[0]
south_central_not_labor_perc = float(df['HC04_EST_VC85'].loc[1])
#print df['HC05_EST_VC85'].loc[0]
south_east_not_labor_perc = float(df['HC05_EST_VC85'].loc[1])
#print df['HC06_EST_VC85'].loc[0]
west_not_labor_perc = float(df['HC06_EST_VC85'].loc[1])

# %%
labels = 'Employed','Unemployed','Not in Labor Force'
sizes = [asian_tot_civ_labor_emp_perc, asian_tot_civ_labor_unemp_perc, asian_tot_not_labor_perc]
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title('Asian Population over 16')
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
 
plt.subplots_adjust(bottom=0.1, right=0.8, top=2)  

labels = 'Labor Force','Not in Labor Force'
colors = ['yellowgreen', 'lightskyblue']
explode = (0, 0)  # only "explode" unemployed

ax1 = fig.add_subplot(6,2,9)
east = [east_labor_perc, east_not_labor_perc]
plt.pie(east, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.8)
plt.axis('equal')
plt.title('East Asian Population over 16')

ax2 = fig.add_subplot(6,2,10)
south_central = [south_central_labor_perc, south_central_not_labor_perc]
plt.pie(south_central, explode=[0.1,0], labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.8)
plt.axis('equal')
plt.title('South Central Asian Population over 16')

ax3 = fig.add_subplot(6,2,11)
south_east = [south_east_labor_perc, south_east_not_labor_perc]
plt.pie(south_east, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.8)
plt.axis('equal')
plt.title('South East Asian Population over 16')

ax4 = fig.add_subplot(6,2,12)
west = [west_labor_perc, west_not_labor_perc]
plt.pie(west, explode=[0,0.1], labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.8)
plt.axis('equal')
plt.title('West Asian Population over 16')
 
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
 
plt.subplots_adjust(bottom=0.1, right=0.8, top=2)  

labels = 'Employed', 'Unemployed'
colors = ['yellowgreen', 'lightskyblue']
explode = (0, 0)  

ax1 = fig.add_subplot(6,2,9)
east = [east_civ_labor_emp_perc_lab, east_civ_labor_unemp_perc_lab]
plt.pie(east, explode=[0.1,0], labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=0, pctdistance=0.8)
plt.axis('equal')
plt.title('East Asian Labor Force')

ax2 = fig.add_subplot(6,2,10)
south_central = [south_central_civ_labor_emp_perc_lab, south_central_civ_labor_unemp_perc_lab]
plt.pie(south_central, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=0, pctdistance=0.8)
plt.axis('equal')
plt.title('South Central Asian Labor Force')

ax3 = fig.add_subplot(6,2,11)
south_east = [south_east_civ_labor_emp_perc_lab, south_east_civ_labor_unemp_perc_lab]
plt.pie(south_east, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=0, pctdistance=0.8)
plt.axis('equal')
plt.title('South East Asian Labor Force')

ax4 = fig.add_subplot(6,2,12)
west = [west_civ_labor_emp_perc_lab, west_civ_labor_unemp_perc_lab]
plt.pie(west, explode=[0,0.1], labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=0, pctdistance=0.8)
plt.axis('equal')
plt.title('West Asian Labor Force')
 
plt.show()

# %%
#print df['HC01_EST_VC95'].loc[0]
tot_manage = float(df['HC01_EST_VC95'].loc[1])
#print df['HC02_EST_VC95'].loc[0]
asian_manage = float(df['HC02_EST_VC95'].loc[1])
#print df['HC03_EST_VC95'].loc[0]
east_manage = float(df['HC03_EST_VC95'].loc[1])
#print df['HC04_EST_VC95'].loc[0]
south_central_manage = float(df['HC04_EST_VC95'].loc[1])
#print df['HC05_EST_VC95'].loc[0]
south_east_manage = float(df['HC05_EST_VC95'].loc[1])
#print df['HC06_EST_VC95'].loc[0]
west_manage = float(df['HC06_EST_VC95'].loc[1])

#print df['HC01_EST_VC96'].loc[0]
tot_service = float(df['HC01_EST_VC96'].loc[1])
#print df['HC02_EST_VC96'].loc[0]
asian_service = float(df['HC02_EST_VC96'].loc[1])
#print df['HC03_EST_VC96'].loc[0]
east_service = float(df['HC03_EST_VC96'].loc[1])
#print df['HC04_EST_VC96'].loc[0]
south_central_service = float(df['HC04_EST_VC96'].loc[1])
#print df['HC05_EST_VC96'].loc[0]
south_east_service = float(df['HC05_EST_VC96'].loc[1])
#print df['HC06_EST_VC96'].loc[0]
west_service = float(df['HC06_EST_VC96'].loc[1])

#print df['HC01_EST_VC97'].loc[0]
tot_sales = float(df['HC01_EST_VC97'].loc[1])
#print df['HC02_EST_VC97'].loc[0]
asian_sales = float(df['HC02_EST_VC97'].loc[1])
#print df['HC03_EST_VC97'].loc[0]
east_sales = float(df['HC03_EST_VC97'].loc[1])
#print df['HC04_EST_VC97'].loc[0]
south_central_sales = float(df['HC04_EST_VC97'].loc[1])
#print df['HC05_EST_VC97'].loc[0]
south_east_sales = float(df['HC05_EST_VC97'].loc[1])
#print df['HC06_EST_VC97'].loc[0]
west_sales = float(df['HC06_EST_VC97'].loc[1])

#print df['HC01_EST_VC98'].loc[0]
tot_maintenance = float(df['HC01_EST_VC98'].loc[1])
#print df['HC02_EST_VC98'].loc[0]
asian_maintenance = float(df['HC02_EST_VC98'].loc[1])
#print df['HC03_EST_VC98'].loc[0]
east_maintenance = float(df['HC03_EST_VC98'].loc[1])
#print df['HC04_EST_VC98'].loc[0]
south_central_maintenance = float(df['HC04_EST_VC98'].loc[1])
#print df['HC05_EST_VC98'].loc[0]
south_east_maintenance = float(df['HC05_EST_VC98'].loc[1])
#print df['HC06_EST_VC98'].loc[0]
west_maintenance = float(df['HC06_EST_VC98'].loc[1])

#print df['HC01_EST_VC99'].loc[0]
tot_moving = float(df['HC01_EST_VC99'].loc[1])
#print df['HC02_EST_VC99'].loc[0]
asian_moving = float(df['HC02_EST_VC99'].loc[1])
#print df['HC03_EST_VC99'].loc[0]
east_moving = float(df['HC03_EST_VC99'].loc[1])
#print df['HC04_EST_VC99'].loc[0]
south_central_moving = float(df['HC04_EST_VC99'].loc[1])
#print df['HC05_EST_VC99'].loc[0]
south_east_moving = float(df['HC05_EST_VC99'].loc[1])
#print df['HC06_EST_VC99'].loc[0]
west_moving = float(df['HC06_EST_VC99'].loc[1])

print tot_manage, tot_service, tot_sales, tot_maintenance, tot_moving
print tot_manage+tot_service+tot_sales+tot_maintenance+tot_moving
# Out:
# 30.3 24.6 17.0 12.9 15.2
# 100.0

# %%
manage = [tot_manage, asian_manage, east_manage, south_central_manage, south_east_manage, west_manage]
service = [tot_service, asian_service, east_service, south_central_service, south_east_service, west_service]
sales = [tot_sales, asian_sales, east_sales, south_central_sales, south_east_sales, west_sales]
maintenance = [tot_maintenance, asian_maintenance, east_maintenance, south_central_maintenance, south_east_maintenance, west_maintenance]
moving = [tot_moving, asian_moving, east_moving, south_central_moving, south_east_moving, west_moving]

X = np.arange(6)
width = 0.5

plt.figure(figsize=(15,9))
p1 = plt.bar(X, manage, color = '#073B4C', width=width)
p2 = plt.bar(X, service, color = '#87CEFA', bottom = manage, width=width)
p3 = plt.bar(X, sales, color='#9ACD32', bottom = [manage[j] + service[j] for j in range(len(manage))], width=width)
p4 = plt.bar(X, maintenance, color='#F08080', bottom = [manage[j] + service[j] + sales[j] for j in range(len(manage))], width=width)
p5 = plt.bar(X, moving, color='#FF7F50', bottom = [manage[j] + service[j] + sales[j] + maintenance[j] for j in range(len(manage))], width=width)
p6 = plt.xticks(X+width/2.,('Total Labor Force','Asian','East','South Central','South East','West'))
plt.xlabel('test')
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0]), ('Management, business, science, arts', 'Service', 'Sales and office', 'Natural resources, construction, and maintenance', 'Production, transportation, and material moving'))
plt.show()

# %%
#print df['HC01_EST_VC117'].loc[0]
tot_earners = float(df['HC01_EST_VC117'].loc[1])
#print df['HC02_EST_VC117'].loc[0]
asian_earners = float(df['HC02_EST_VC117'].loc[1])
#print df['HC03_EST_VC117'].loc[0]
east_earners = float(df['HC03_EST_VC117'].loc[1])
#print df['HC04_EST_VC117'].loc[0]
south_central_earners = float(df['HC04_EST_VC117'].loc[1])
#print df['HC05_EST_VC117'].loc[0]
south_east_earners = float(df['HC05_EST_VC117'].loc[1])
#print df['HC06_EST_VC117'].loc[0]
west_earners = float(df['HC06_EST_VC117'].loc[1])

#print df['HC01_EST_VC118'].loc[0]
tot_1_9999 = float(df['HC01_EST_VC118'].loc[1])
#print df['HC02_EST_VC118'].loc[0]
asian_1_9999 = float(df['HC02_EST_VC118'].loc[1])
#print df['HC03_EST_VC118'].loc[0]
east_1_9999 = float(df['HC03_EST_VC118'].loc[1])
#print df['HC04_EST_VC118'].loc[0]
south_central_1_9999 = float(df['HC04_EST_VC118'].loc[1])
#print df['HC05_EST_VC118'].loc[0]
south_east_1_9999 = float(df['HC05_EST_VC118'].loc[1])
#print df['HC06_EST_VC118'].loc[0]
west_1_9999 = float(df['HC06_EST_VC118'].loc[1])

#print df['HC01_EST_VC119'].loc[0]
tot_10000_14999 = float(df['HC01_EST_VC119'].loc[1])
#print df['HC02_EST_VC119'].loc[0]
asian_10000_14999 = float(df['HC02_EST_VC119'].loc[1])
#print df['HC03_EST_VC119'].loc[0]
east_10000_14999 = float(df['HC03_EST_VC119'].loc[1])
#print df['HC04_EST_VC119'].loc[0]
south_central_10000_14999 = float(df['HC04_EST_VC119'].loc[1])
#print df['HC05_EST_VC119'].loc[0]
south_east_10000_14999 = float(df['HC05_EST_VC119'].loc[1])
#print df['HC06_EST_VC119'].loc[0]
west_10000_14999 = float(df['HC06_EST_VC119'].loc[1])

#print df['HC01_EST_VC120'].loc[0]
tot_15000_24999 = float(df['HC01_EST_VC120'].loc[1])
#print df['HC02_EST_VC120'].loc[0]
asian_15000_24999 = float(df['HC02_EST_VC120'].loc[1])
#print df['HC03_EST_VC120'].loc[0]
east_15000_24999 = float(df['HC03_EST_VC120'].loc[1])
#print df['HC04_EST_VC120'].loc[0]
south_central_15000_24999 = float(df['HC04_EST_VC120'].loc[1])
#print df['HC05_EST_VC120'].loc[0]
south_east_15000_24999 = float(df['HC05_EST_VC120'].loc[1])
#print df['HC06_EST_VC120'].loc[0]
west_15000_24999 = float(df['HC06_EST_VC120'].loc[1])

#print df['HC01_EST_VC121'].loc[0]
tot_25000_34999 = float(df['HC01_EST_VC121'].loc[1])
#print df['HC02_EST_VC121'].loc[0]
asian_25000_34999 = float(df['HC02_EST_VC121'].loc[1])
#print df['HC03_EST_VC121'].loc[0]
east_25000_34999 = float(df['HC03_EST_VC121'].loc[1])
#print df['HC04_EST_VC121'].loc[0]
south_central_25000_34999 = float(df['HC04_EST_VC121'].loc[1])
#print df['HC05_EST_VC121'].loc[0]
south_east_25000_34999 = float(df['HC05_EST_VC121'].loc[1])
#print df['HC06_EST_VC121'].loc[0]
west_25000_34999 = float(df['HC06_EST_VC121'].loc[1])

#print df['HC01_EST_VC122'].loc[0]
tot_35000_49999 = float(df['HC01_EST_VC122'].loc[1])
#print df['HC02_EST_VC122'].loc[0]
asian_35000_49999 = float(df['HC02_EST_VC122'].loc[1])
#print df['HC03_EST_VC122'].loc[0]
east_35000_49999 = float(df['HC03_EST_VC122'].loc[1])
#print df['HC04_EST_VC122'].loc[0]
south_central_35000_49999 = float(df['HC04_EST_VC122'].loc[1])
#print df['HC05_EST_VC122'].loc[0]
south_east_35000_49999 = float(df['HC05_EST_VC122'].loc[1])
#print df['HC06_EST_VC122'].loc[0]
west_35000_49999 = float(df['HC06_EST_VC122'].loc[1])

#print df['HC01_EST_VC123'].loc[0]
tot_50000_74999 = float(df['HC01_EST_VC123'].loc[1])
#print df['HC02_EST_VC123'].loc[0]
asian_50000_74999 = float(df['HC02_EST_VC123'].loc[1])
#print df['HC03_EST_VC123'].loc[0]
east_50000_74999 = float(df['HC03_EST_VC123'].loc[1])
#print df['HC04_EST_VC123'].loc[0]
south_central_50000_74999 = float(df['HC04_EST_VC123'].loc[1])
#print df['HC05_EST_VC123'].loc[0]
south_east_50000_74999 = float(df['HC05_EST_VC123'].loc[1])
#print df['HC06_EST_VC123'].loc[0]
west_50000_74999 = float(df['HC06_EST_VC123'].loc[1])

#print df['HC01_EST_VC124'].loc[0]
tot_75000_up = float(df['HC01_EST_VC124'].loc[1])
#print df['HC02_EST_VC124'].loc[0]
asian_75000_up = float(df['HC02_EST_VC124'].loc[1])
#print df['HC03_EST_VC124'].loc[0]
east_75000_up = float(df['HC03_EST_VC124'].loc[1])
#print df['HC04_EST_VC124'].loc[0]
south_central_75000_up = float(df['HC04_EST_VC124'].loc[1])
#print df['HC05_EST_VC124'].loc[0]
south_east_75000_up = float(df['HC05_EST_VC124'].loc[1])
#print df['HC06_EST_VC124'].loc[0]
west_75000_up = float(df['HC06_EST_VC124'].loc[1])

# %%
earn_1_9999 = [tot_1_9999, asian_1_9999, east_1_9999, south_central_1_9999, south_east_1_9999, west_1_9999]
earn_10000_14999 = [tot_10000_14999, asian_10000_14999, east_10000_14999, south_central_10000_14999, south_east_10000_14999, west_10000_14999]
earn_15000_24999 = [tot_15000_24999, asian_15000_24999, east_15000_24999, south_central_15000_24999, south_east_15000_24999, west_15000_24999]
earn_25000_34999 = [tot_25000_34999, asian_25000_34999, east_25000_34999, south_central_25000_34999, south_east_25000_34999, west_25000_34999]
earn_35000_49999 = [tot_35000_49999, asian_35000_49999, east_35000_49999, south_central_35000_49999, south_east_35000_49999, west_35000_49999]
earn_50000_74999 = [tot_50000_74999, asian_50000_74999, east_50000_74999, south_central_50000_74999, south_east_50000_74999, west_50000_74999]
earn_75000_up = [tot_75000_up, asian_75000_up, east_75000_up, south_central_75000_up, south_east_75000_up, west_75000_up]

X = np.arange(6)
width = 0.5
plt.figure(figsize=(15,12))
p1 = plt.bar(X,earn_1_9999, color = '#073B4C', width=width)
p2 = plt.bar(X,earn_10000_14999, color = '#87CEFA', bottom = [earn_1_9999[j] for j in range(len(earn_1_9999))], width=width)
p3 = plt.bar(X,earn_15000_24999, color='#9ACD32', bottom = [earn_1_9999[j] + earn_10000_14999[j] for j in range(len(earn_1_9999))], width=width)
p4 = plt.bar(X,earn_25000_34999, color='#F08080', bottom = [earn_1_9999[j] + earn_10000_14999[j] + earn_15000_24999[j] for j in range(len(earn_1_9999))], width=width)
p5 = plt.bar(X,earn_35000_49999, color='#FF7F50', bottom = [earn_1_9999[j] + earn_10000_14999[j] + earn_15000_24999[j] + earn_25000_34999[j] for j in range(len(earn_1_9999))], width=width)
p6 = plt.bar(X,earn_50000_74999, color='#ff5a1d', bottom = [earn_1_9999[j] + earn_10000_14999[j] + earn_15000_24999[j] + earn_25000_34999[j] + earn_35000_49999[j] for j in range(len(earn_1_9999))], width=width)
p7 = plt.bar(X,earn_75000_up, color='#ffcb1d', bottom = [earn_1_9999[j] + earn_10000_14999[j] + earn_15000_24999[j] + earn_25000_34999[j] + earn_35000_49999[j] + earn_50000_74999[j] for j in range(len(earn_1_9999))], width=width)
p8 = plt.xticks(X+width/2.,('Total Labor Force','Asian','East','South Central','South East','West'))
plt.xlabel('test')
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0], p7[0]), ('$1-9999 or less','$10000-14999','$15000-24999','$25000-34999','$35000-49999','$50000-74999','$75000 and up'))
plt.show()
