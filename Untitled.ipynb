# %%
import pandas 
import numpy
import matplotlib.pyplot as plt
import importingData
# %matplotlib inline
# Out:
# /home/casey/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
def make_piBar(things2Plot, labels, title):
    labels = labels
    sizes = things2Plot
    colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
    patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
    plt.legend(patches, labels, loc="best")
    plt.axis('equal')
    plt.tight_layout()
    plt.title(title)
    plt.show()

# %%
def make_piBar_multiple(things2Plot1, things2Plot2, things2Plot3):
    plt.figure(figsize=(20, 7))
    ax1 = plt.subplot(1, 4, 1)
    labels = ['Nursery School', 'Elementary School', 'High School', 'College']
    colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
    patches= plt.pie(things2Plot1, colors=colors, autopct='%1.1f%%')
    plt.legend(patches, labels = labels, loc="best")
    plt.tight_layout()
    plt.title('Europeans enrolled in School', fontsize = 15)
    
    ax2 = plt.subplot(1, 4, 2)
    colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
    patches= plt.pie(things2Plot2, colors=colors, autopct='%1.1f%%')
    plt.legend(patches, labels = labels, loc="best")
    plt.tight_layout()
    plt.title('Northern and Western Europeans enrolled in School', fontsize = 15)
    
    ax3 = plt.subplot(1, 4, 3)
    colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
    patches= plt.pie(things2Plot3, colors=colors, autopct='%1.1f%%')
    plt.legend(patches, labels = labels, loc="best")
    plt.tight_layout()
    plt.title('Southern and Eastern Europeans enrolled in School', fontsize = 15)

    
    plt.show()

# %% [markdown]
# First, we are importing the data from the EuropeanData class in importingData.py file.

# %%
europeanData = importingData.EuropeanData()
df_europe_2014 = europeanData.european_data_2014

# %% [markdown]
# We can print the head of the data frame. For some reason, the GEO.id2 is NaN. However, this is not important to the data we need.

# %%
df_europe_2014.head()
# Out:
#       GEO.id GEO.id2 GEO.display-label  \
# 0         Id     Id2         Geography
# 1  0100000US     NaN     United States
#
#                               HC01_EST_VC01  \
# 0  Total; Estimate; Foreign-born population
# 1                                  42391794
#
#                                      HC01_MOE_VC01  \
# 0  Total; Margin of Error; Foreign-born population
# 1                                           130122
#
#                                        HC02_EST_VC01  \
# 0  Foreign born; Born in Europe; Estimate; Foreig...
# 1                                            4764822
#
#                                        HC02_MOE_VC01  \
# 0  Foreign born; Born in Europe; Margin of Error;...
# 1                                              45299
#
#                                        HC03_EST_VC01  \
# 0  Foreign born; Born in Northern and Western Eur...
# 1                                            1890373
#
# ...

# %% [markdown]
# Plotting the schools European students are enrolled in for each region. We would like to see where the students are, grade wise, by plotting the pie bars and comparing.

# %%
enrolled_in_school_total_europe = europeanData.enrolled_in_school_total()
enrolled_in_school_born_in_europe = europeanData.enrolled_in_school_born_in_Europe()
enrolled_in_school_born_in_nothern_and_western_europe = europeanData.enrolled_in_school_born_in_Nothern_and_Western_Europe()
enrolled_in_school_born_in_southern_and_eastern_europe = europeanData.enrolled_in_school_born_in_Southern_and_Eastern_Europe()

# %%
print enrolled_in_school_born_in_europe 
print enrolled_in_school_born_in_nothern_and_western_europe
print enrolled_in_school_born_in_southern_and_eastern_europe
# Out:
# ['517497', '2.0', '21.1', '18.1', '58.7']
# ['185876', '3.1', '21.2', '16.9', '58.8']
# ['330305', '1.4', '21.2', '18.8', '58.6']

# %%
make_piBar_multiple(enrolled_in_school_born_in_europe[1:5], 
                    enrolled_in_school_born_in_nothern_and_western_europe[1:5], enrolled_in_school_born_in_southern_and_eastern_europe[1:5])
# Out:
# /home/casey/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:492: UserWarning: You have mixed positional and keyword arguments, some input will be discarded.
#   warnings.warn("You have mixed positional and keyword "

# %% [markdown]
# Interestingly enough, the percentages in each grade are about the same for all Europeans. There isn't much variation on which grade they are enrolled in. About 1% are enrolled in nursery school, 21% are enrolled in elementary school, 18% are enrolled in college and 58% are enrolled in college. Again, we see that the majority of the people in school are in college.

# %% [markdown]
# Now we want to compare the level of education attainment each type of European recieved. We want to know what type of degree they have and for people over 25, what their education background is like. We have this information and we can plot it below.

# %% [markdown]
# First we have to collect the data of the education level of each region.

# %%
ed_attainment_europe = europeanData.educ_attainment_born_in_Europe()
ed_attainment_northern_and_western_europe = europeanData.educ_attainment_born_in_Northern_and_Western_Europe()
ed_attainment_southern_and_eastern_europe = europeanData.educ_attainment_born_in_Southern_and_Eastern_Europe()
# Out:
# ['4302760', '12.9', '23.8', '23.1', '20.2', '20.0']

# %%
X = numpy.arange(5)
width = 0.2
plt.figure(figsize=(15,11))
p1 = plt.bar([i-0.2 for i in X], ed_attainment_europe[1:6], color = '#073B4C', width=width)
p2 = plt.bar(X, ed_attainment_northern_and_western_europe[1:6], color='#9ACD32', width = width)
p3 = plt.bar([i+0.2 for i in X],ed_attainment_southern_and_eastern_europe[1:6], color='#F08080', width = width)
p4 = plt.xticks(X+width/2.,('< H.S edu','H.S education','Some college','Bachelors degree','Graduate Degree'), fontsize=16)
plt.xlabel('Degree', fontsize=16)
plt.ylabel('Percentage of European Foreigners earning these degrees of education', fontsize=16)
plt.title('Degrees Obtained By European Foreign Born Population', fontsize = 25)
plt.legend((p1[0], p2[0], p3[0], p4[0]), ('Born in Europe', 'Born in Northern or Western Europe', 'Born in Southern or Eastern Europe'), fontsize=12, loc = "best")
plt.show()

# %% [markdown]
# The graph above shows that the majority of Europeans from North or Western Europe have some college, and the second highest is a high school education. This graph also follows the Gaussian distribution. The peak for southern and eatern europeans is a high school education. Only around 18% of Europeans have a bachelors degree and slightly less of them have a graduate degree.
