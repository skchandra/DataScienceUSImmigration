# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /home/kiki/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/kiki/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
df = pd.read_csv('African_Northern_America_and_Oceania_ACS_Foreign_Born_Characteristics.csv')
df_asia = pd.read_csv('Asian_ACS_Foreign_Born_Characteristics_2014.csv')
df_europe = pd.read_csv('Europe_ACS_Foreign_Born_Characteristics_14.csv')
df_latin = pd.read_csv('Latin_America_ACS_Foreign_Born_Characteristics_14.csv')
df
# Out:
#       GEO.id GEO.id2 GEO.display-label  \
# 0         Id     Id2         Geography
# 1  0100000US     NaN     United States
#
#                               HC01_EST_VC01  \
# 0  Total; Estimate; Foreign-born population
# 1                                  42391794
#
#                                      HC01_MOE_VC01  \
# 0  Total; Margin of Error; Foreign-born population
# 1                                           130122
#
#                                        HC02_EST_VC01  \
# 0  Foreign born; Born in Africa; Estimate; Foreig...
# 1                                            1931203
#
#                                        HC02_MOE_VC01  \
# 0  Foreign born; Born in Africa; Margin of Error;...
# 1                                              35812
#
#                                        HC03_EST_VC01  \
# 0  Foreign born; Born in Northern America; Estima...
# 1                                             812642
#
# ...

# %%
#print df['HC01_EST_VC78'].loc[0]
tot_pop_16 = float(df['HC01_EST_VC78'].loc[1])
#print df['HC02_EST_VC78'].loc[0]
africa_tot_pop_16 = float(df['HC02_EST_VC78'].loc[1])
#print df['HC03_EST_VC78'].loc[0]
northa_pop_16 = float(df['HC03_EST_VC78'].loc[1])
#print df['HC04_EST_VC78'].loc[0]
oceania_pop_16 = float(df['HC04_EST_VC78'].loc[1])
#print df_asia['HC02_EST_VC78'].loc[0]
asian_tot_pop_16 = float(df_asia['HC02_EST_VC78'].loc[1])
#print df_europe['HC02_EST_VC78'].loc[0]
europe_tot_pop_16 = float(df_europe['HC02_EST_VC78'].loc[1])
#print df_latin['HC02_EST_VC78'].loc[0]
latin_tot_pop_16 = float(df_latin['HC02_EST_VC78'].loc[1])


#print df['HC01_EST_VC79'].loc[0]
tot_labor_perc = float(df['HC01_EST_VC79'].loc[1])
#print df['HC02_EST_VC79'].loc[0]
africa_labor_perc = float(df['HC02_EST_VC79'].loc[1])
#print df['HC03_EST_VC79'].loc[0]
northa_labor_perc = float(df['HC03_EST_VC79'].loc[1])
#print df['HC04_EST_VC79'].loc[0]
oceania_labor_perc = float(df['HC04_EST_VC79'].loc[1])
#print df_asia['HC02_EST_VC79'].loc[0]
asian_tot_labor_perc = float(df_asia['HC02_EST_VC79'].loc[1])
#print df_europe['HC02_EST_VC79'].loc[0]
europe_tot_labor_perc = float(df_europe['HC02_EST_VC79'].loc[1])
#print df_latin['HC02_EST_VC79'].loc[0]
latin_tot_labor_perc = float(df_latin['HC02_EST_VC79'].loc[1])

#print df['HC01_EST_VC80'].loc[0]
tot_civ_labor_perc = float(df['HC01_EST_VC80'].loc[1])
#print df['HC02_EST_VC80'].loc[0]
africa_civ_labor_perc = float(df['HC02_EST_VC80'].loc[1])
#print df['HC03_EST_VC80'].loc[0]
northa_civ_labor_perc = float(df['HC03_EST_VC80'].loc[1])
#print df['HC04_EST_VC80'].loc[0]
oceania_civ_labor_perc = float(df['HC04_EST_VC80'].loc[1])
#print df_asia['HC02_EST_VC80'].loc[0]
asia_tot_civ_labor_perc = float(df_asia['HC02_EST_VC80'].loc[1])
#print df_europe['HC02_EST_VC80'].loc[0]
europe_tot_civ_labor_perc = float(df_europe['HC02_EST_VC80'].loc[1])
#print df_latin['HC02_EST_VC80'].loc[0]
latin_tot_civ_labor_perc = float(df_latin['HC02_EST_VC80'].loc[1])

#print df['HC01_EST_VC81'].loc[0]
tot_civ_labor_emp_perc = float(df['HC01_EST_VC81'].loc[1])
#print df['HC02_EST_VC81'].loc[0]
africa_civ_labor_emp_perc = float(df['HC02_EST_VC81'].loc[1])
#print df['HC03_EST_VC81'].loc[0]
northa_civ_labor_emp_perc = float(df['HC03_EST_VC81'].loc[1])
#print df['HC04_EST_VC81'].loc[0]
oceania_civ_labor_emp_perc = float(df['HC04_EST_VC81'].loc[1])
#print df_asia['HC02_EST_VC81'].loc[0]
asia_civ_labor_emp_perc = float(df_asia['HC02_EST_VC81'].loc[1])
#print df_europe['HC02_EST_VC81'].loc[0]
europe_civ_labor_emp_perc = float(df_europe['HC02_EST_VC81'].loc[1])
#print df_latin['HC02_EST_VC81'].loc[0]
latin_civ_labor_emp_perc = float(df_latin['HC02_EST_VC81'].loc[1])

tot_civ_labor_emp_perc_lab = tot_civ_labor_emp_perc/tot_civ_labor_perc*100
africa_civ_labor_emp_perc_lab = africa_civ_labor_emp_perc/africa_civ_labor_perc*100
northa_civ_labor_emp_perc_lab = northa_civ_labor_emp_perc/northa_civ_labor_perc*100
oceania_civ_labor_emp_perc_lab = oceania_civ_labor_emp_perc/oceania_civ_labor_perc*100
asia_civ_labor_emp_perc_lab = asia_civ_labor_emp_perc/asia_tot_civ_labor_perc*100
europe_civ_labor_emp_perc_lab = europe_civ_labor_emp_perc/europe_tot_civ_labor_perc*100
latin_civ_labor_emp_perc_lab = latin_civ_labor_emp_perc/latin_tot_civ_labor_perc*100

#print df['HC01_EST_VC82'].loc[0]
tot_civ_labor_unemp_perc = float(df['HC01_EST_VC82'].loc[1])
#print df['HC02_EST_VC82'].loc[0]
africa_civ_labor_unemp_perc = float(df['HC02_EST_VC82'].loc[1])
#print df['HC03_EST_VC82'].loc[0]
northa_civ_labor_unemp_perc = float(df['HC03_EST_VC82'].loc[1])
#print df['HC04_EST_VC82'].loc[0]
oceania_civ_labor_unemp_perc = float(df['HC04_EST_VC82'].loc[1])
#print df_asia['HC02_EST_VC82'].loc[0]
asia_civ_labor_unemp_perc = float(df_asia['HC02_EST_VC82'].loc[1])
#print df_europe['HC02_EST_VC82'].loc[0]
europe_civ_labor_unemp_perc = float(df_europe['HC02_EST_VC82'].loc[1])
#print df_asia['HC02_EST_VC82'].loc[0]
latin_civ_labor_unemp_perc = float(df_latin['HC02_EST_VC82'].loc[1])

#print df['HC01_EST_VC83'].loc[0]
tot_civ_labor_unemp_perc_lab = float(df['HC01_EST_VC83'].loc[1])
#print df['HC02_EST_VC83'].loc[0]
africa_civ_labor_unemp_perc_lab = float(df['HC02_EST_VC83'].loc[1])
#print df['HC03_EST_VC83'].loc[0]
northa_civ_labor_unemp_perc_lab = float(df['HC03_EST_VC83'].loc[1])
#print df['HC04_EST_VC83'].loc[0]
oceania_civ_labor_unemp_perc_lab = float(df['HC04_EST_VC83'].loc[1])
#print df_asia['HC02_EST_VC83'].loc[0]
asia_civ_labor_unemp_perc_lab = float(df_asia['HC02_EST_VC83'].loc[1])
#print df_europe['HC02_EST_VC83'].loc[0]
europe_civ_labor_unemp_perc_lab = float(df_europe['HC02_EST_VC83'].loc[1])
#print df_latin['HC02_EST_VC83'].loc[0]
latin_civ_labor_unemp_perc_lab = float(df_latin['HC02_EST_VC83'].loc[1])

#print df['HC01_EST_VC85'].loc[0]
tot_not_labor_perc = float(df['HC01_EST_VC85'].loc[1])
#print df['HC02_EST_VC85'].loc[0]
africa_not_labor_perc = float(df['HC02_EST_VC85'].loc[1])
#print df['HC03_EST_VC85'].loc[0]
northa_not_labor_perc = float(df['HC03_EST_VC85'].loc[1])
#print df['HC04_EST_VC85'].loc[0]
oceania_not_labor_perc = float(df['HC04_EST_VC85'].loc[1])
#print df_asia['HC02_EST_VC85'].loc[0]
asia_not_labor_perc = float(df_asia['HC02_EST_VC85'].loc[1])
#print df_europe['HC02_EST_VC85'].loc[0]
europe_not_labor_perc = float(df_europe['HC02_EST_VC85'].loc[1])
#print df_latin['HC02_EST_VC85'].loc[0]
latin_not_labor_perc = float(df_latin['HC02_EST_VC85'].loc[1])

# %%
#fig = plt.figure(figsize=(20,10))
 
#plt.subplots_adjust(bottom=0.1, right=0.8, top=2)  

labels = 'Employed','Unemployed','Not in Labor Force'
sizes = [tot_civ_labor_emp_perc, tot_civ_labor_unemp_perc, tot_not_labor_perc]
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title('Total US Population over 16')
plt.show()

# %%
labels = 'Employed','Unemployed','Not in Labor Force'
sizes = [africa_civ_labor_emp_perc, africa_civ_labor_unemp_perc, africa_not_labor_perc]
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title('African Population over 16')
plt.show()

# %%
labels = 'Employed','Unemployed','Not in Labor Force'
sizes = [northa_civ_labor_emp_perc, northa_civ_labor_unemp_perc, northa_not_labor_perc]
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title('North American Population over 16')
plt.show()

# %%
labels = 'Employed','Unemployed','Not in Labor Force'
sizes = [oceania_civ_labor_emp_perc, oceania_civ_labor_unemp_perc, oceania_not_labor_perc]
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title('Oceanic Population over 16')
plt.show()

# %%
labels = 'Employed','Unemployed','Not in Labor Force'
sizes = [asia_civ_labor_emp_perc, asia_civ_labor_unemp_perc, asia_not_labor_perc]
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title('Asian Population over 16')
plt.show()

# %%
labels = 'Employed','Unemployed','Not in Labor Force'
sizes = [europe_civ_labor_emp_perc, europe_civ_labor_unemp_perc, europe_not_labor_perc]
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title('European Population over 16')
plt.show()

# %%
labels = 'Employed','Unemployed','Not in Labor Force'
sizes = [latin_civ_labor_emp_perc, latin_civ_labor_unemp_perc, latin_not_labor_perc]
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title('Latin American Population over 16')
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
 
plt.subplots_adjust(bottom=0.1, right=0.8, top=2)  

labels = 'Labor Force','Not in Labor Force'
colors = ['yellowgreen', 'lightskyblue']
explode = (0, 0)  # only "explode" unemployed

ax1 = fig.add_subplot(6,2,9)
asia = [asian_tot_labor_perc, asia_not_labor_perc]
plt.pie(asia, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.8)
plt.axis('equal')
plt.title('Asian Population over 16')

ax2 = fig.add_subplot(6,2,10)
africa = [africa_labor_perc, africa_not_labor_perc]
plt.pie(africa, explode=[0.1,0], labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.8)
plt.axis('equal')
plt.title('African Population over 16')

ax3 = fig.add_subplot(6,2,11)
northa = [northa_labor_perc, northa_not_labor_perc]
plt.pie(northa, explode=[0,0.1], labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.8)
plt.axis('equal')
plt.title('North American Population over 16')

ax4 = fig.add_subplot(6,2,12)
oceania = [oceania_labor_perc, oceania_not_labor_perc]
plt.pie(oceania, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.8)
plt.axis('equal')
plt.title('Oceanic Population over 16')
 
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
 
plt.subplots_adjust(bottom=0.1, right=0.8, top=2)  

labels = 'Employed', 'Unemployed'
colors = ['yellowgreen', 'lightskyblue']
explode = (0, 0)  

ax1 = fig.add_subplot(6,2,9)
asia = [asia_civ_labor_emp_perc_lab, asia_civ_labor_unemp_perc_lab]
plt.pie(asia, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=0, pctdistance=0.8)
plt.axis('equal')
plt.title('Asian Labor Force')

ax2 = fig.add_subplot(6,2,10)
africa = [africa_civ_labor_emp_perc_lab, africa_civ_labor_unemp_perc_lab]
plt.pie(africa, explode=[0.1,0], labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=0, pctdistance=0.8)
plt.axis('equal')
plt.title('African Labor Force')

ax3 = fig.add_subplot(6,2,11)
northa = [northa_civ_labor_emp_perc_lab, northa_civ_labor_unemp_perc_lab]
plt.pie(northa, explode=[0,0.1], labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=0, pctdistance=0.8)
plt.axis('equal')
plt.title('North American Labor Force')

ax4 = fig.add_subplot(6,2,12)
oceania = [oceania_civ_labor_emp_perc_lab, oceania_civ_labor_unemp_perc_lab]
plt.pie(oceania, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=0, pctdistance=0.8)
plt.axis('equal')
plt.title('Oceanic Labor Force')
 
plt.show()

# %%
#print df['HC01_EST_VC95'].loc[0]
tot_manage = float(df['HC01_EST_VC95'].loc[1])
#print df['HC02_EST_VC95'].loc[0]
africa_manage = float(df['HC02_EST_VC95'].loc[1])
#print df['HC03_EST_VC95'].loc[0]
northa_manage = float(df['HC03_EST_VC95'].loc[1])
#print df['HC04_EST_VC95'].loc[0]
oceania_manage = float(df['HC04_EST_VC95'].loc[1])
#print df_asia['HC02_EST_VC95'].loc[0]
asian_manage = float(df_asia['HC02_EST_VC95'].loc[1])

#print df['HC01_EST_VC96'].loc[0]
tot_service = float(df['HC01_EST_VC96'].loc[1])
#print df['HC02_EST_VC96'].loc[0]
africa_service = float(df['HC02_EST_VC96'].loc[1])
#print df['HC03_EST_VC96'].loc[0]
northa_service = float(df['HC03_EST_VC96'].loc[1])
#print df['HC04_EST_VC96'].loc[0]
oceania_service = float(df['HC04_EST_VC96'].loc[1])
#print df_asia['HC02_EST_VC96'].loc[0]
asian_service = float(df_asia['HC02_EST_VC96'].loc[1])

#print df['HC01_EST_VC97'].loc[0]
tot_sales = float(df['HC01_EST_VC97'].loc[1])
#print df['HC02_EST_VC97'].loc[0]
africa_sales = float(df['HC02_EST_VC97'].loc[1])
#print df['HC03_EST_VC97'].loc[0]
northa_sales = float(df['HC03_EST_VC97'].loc[1])
#print df['HC04_EST_VC97'].loc[0]
oceania_sales = float(df['HC04_EST_VC97'].loc[1])
#print df_asia['HC02_EST_VC97'].loc[0]
asian_sales = float(df_asia['HC02_EST_VC97'].loc[1])

#print df['HC01_EST_VC98'].loc[0]
tot_maintenance = float(df['HC01_EST_VC98'].loc[1])
#print df['HC02_EST_VC98'].loc[0]
africa_maintenance = float(df['HC02_EST_VC98'].loc[1])
#print df['HC03_EST_VC98'].loc[0]
northa_maintenance = float(df['HC03_EST_VC98'].loc[1])
#print df['HC04_EST_VC98'].loc[0]
oceania_maintenance = float(df['HC04_EST_VC98'].loc[1])
#print df_asia['HC02_EST_VC98'].loc[0]
asian_maintenance = float(df_asia['HC02_EST_VC98'].loc[1])

#print df['HC01_EST_VC99'].loc[0]
tot_moving = float(df['HC01_EST_VC99'].loc[1])
#print df['HC02_EST_VC99'].loc[0]
africa_moving = float(df['HC02_EST_VC99'].loc[1])
#print df['HC03_EST_VC99'].loc[0]
northa_moving = float(df['HC03_EST_VC99'].loc[1])
#print df['HC04_EST_VC99'].loc[0]
oceania_moving = float(df['HC04_EST_VC99'].loc[1])
#print df_asia['HC02_EST_VC99'].loc[0]
asian_moving = float(df_asia['HC02_EST_VC99'].loc[1])

print tot_manage, tot_service, tot_sales, tot_maintenance, tot_moving
print tot_manage+tot_service+tot_sales+tot_maintenance+tot_moving
# Out:
# 30.3 24.6 17.0 12.9 15.2
# 100.0

# %%
manage = [tot_manage, africa_manage, northa_manage, oceania_manage, asian_manage]
service = [tot_service, africa_service, northa_service, oceania_service, asian_service]
sales = [tot_sales, africa_sales, northa_sales, oceania_sales, asian_sales]
maintenance = [tot_maintenance, africa_maintenance, northa_maintenance, oceania_maintenance, asian_maintenance]
moving = [tot_moving, africa_moving, northa_moving, oceania_moving, asian_moving]

X = np.arange(5)
width = 0.5

plt.figure(figsize=(15,11))
p1 = plt.bar(X, manage, color = '#073B4C', width=width)
p2 = plt.bar(X, service, color = '#87CEFA', bottom = manage, width=width)
p3 = plt.bar(X, sales, color='#9ACD32', bottom = [manage[j] + service[j] for j in range(len(manage))], width=width)
p4 = plt.bar(X, maintenance, color='#F08080', bottom = [manage[j] + service[j] + sales[j] for j in range(len(manage))], width=width)
p5 = plt.bar(X, moving, color='#FF7F50', bottom = [manage[j] + service[j] + sales[j] + maintenance[j] for j in range(len(manage))], width=width)
p6 = plt.xticks(X+width/2.,('Overall Labor Force in US','African','North American','Oceanic','Asian'), fontsize=16)
plt.xlabel('Place of Origin', fontsize=16)
plt.ylabel('Percentage of Labor Force', fontsize=16)
plt.title('Labor Force by Place of Origin', fontsize=16)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0]), ('Management, business, science, arts', 'Service', 'Sales and office', 'Natural resources, construction, and maintenance', 'Production, transportation, and material moving'), fontsize=12)
plt.show()

# %%
#print df['HC01_EST_VC117'].loc[0]
tot_earners = float(df['HC01_EST_VC117'].loc[1])
#print df['HC02_EST_VC117'].loc[0]
africa_earners = float(df['HC02_EST_VC117'].loc[1])
#print df['HC03_EST_VC117'].loc[0]
northa_earners = float(df['HC03_EST_VC117'].loc[1])
#print df['HC04_EST_VC117'].loc[0]
oceania_earners = float(df['HC04_EST_VC117'].loc[1])
#print df_asia['HC02_EST_VC117'].loc[0]
asian_earners = float(df_asia['HC02_EST_VC117'].loc[1])

#print df['HC01_EST_VC118'].loc[0]
tot_1_9999 = float(df['HC01_EST_VC118'].loc[1])
#print df['HC02_EST_VC118'].loc[0]
africa_1_9999 = float(df['HC02_EST_VC118'].loc[1])
#print df['HC03_EST_VC118'].loc[0]
northa_1_9999 = float(df['HC03_EST_VC118'].loc[1])
#print df['HC04_EST_VC118'].loc[0]
oceania_1_9999 = float(df['HC04_EST_VC118'].loc[1])
#print df_asia['HC02_EST_VC118'].loc[0]
asian_1_9999 = float(df_asia['HC02_EST_VC118'].loc[1])

#print df['HC01_EST_VC119'].loc[0]
tot_10000_14999 = float(df['HC01_EST_VC119'].loc[1])
#print df['HC02_EST_VC119'].loc[0]
africa_10000_14999 = float(df['HC02_EST_VC119'].loc[1])
#print df['HC03_EST_VC119'].loc[0]
northa_10000_14999 = float(df['HC03_EST_VC119'].loc[1])
#print df['HC04_EST_VC119'].loc[0]
oceania_10000_14999 = float(df['HC04_EST_VC119'].loc[1])
#print df_asia['HC02_EST_VC119'].loc[0]
asian_10000_14999 = float(df_asia['HC02_EST_VC119'].loc[1])

#print df['HC01_EST_VC120'].loc[0]
tot_15000_24999 = float(df['HC01_EST_VC120'].loc[1])
#print df['HC02_EST_VC120'].loc[0]
africa_15000_24999 = float(df['HC02_EST_VC120'].loc[1])
#print df['HC03_EST_VC120'].loc[0]
northa_15000_24999 = float(df['HC03_EST_VC120'].loc[1])
#print df['HC04_EST_VC120'].loc[0]
oceania_15000_24999 = float(df['HC04_EST_VC120'].loc[1])
#print df_asia['HC02_EST_VC120'].loc[0]
asian_15000_24999 = float(df_asia['HC02_EST_VC120'].loc[1])

#print df['HC01_EST_VC121'].loc[0]
tot_25000_34999 = float(df['HC01_EST_VC121'].loc[1])
#print df['HC02_EST_VC121'].loc[0]
africa_25000_34999 = float(df['HC02_EST_VC121'].loc[1])
#print df['HC03_EST_VC121'].loc[0]
northa_25000_34999 = float(df['HC03_EST_VC121'].loc[1])
#print df['HC04_EST_VC121'].loc[0]
oceania_25000_34999 = float(df['HC04_EST_VC121'].loc[1])
#print df_asia['HC02_EST_VC121'].loc[0]
asian_25000_34999 = float(df_asia['HC02_EST_VC121'].loc[1])

#print df['HC01_EST_VC122'].loc[0]
tot_35000_49999 = float(df['HC01_EST_VC122'].loc[1])
#print df['HC02_EST_VC122'].loc[0]
africa_35000_49999 = float(df['HC02_EST_VC122'].loc[1])
#print df['HC03_EST_VC122'].loc[0]
northa_35000_49999 = float(df['HC03_EST_VC122'].loc[1])
#print df['HC04_EST_VC122'].loc[0]
oceania_35000_49999 = float(df['HC04_EST_VC122'].loc[1])
#print df_asia['HC02_EST_VC122'].loc[0]
asian_35000_49999 = float(df_asia['HC02_EST_VC122'].loc[1])

#print df['HC01_EST_VC123'].loc[0]
tot_50000_74999 = float(df['HC01_EST_VC123'].loc[1])
#print df['HC02_EST_VC123'].loc[0]
africa_50000_74999 = float(df['HC02_EST_VC123'].loc[1])
#print df['HC03_EST_VC123'].loc[0]
northa_50000_74999 = float(df['HC03_EST_VC123'].loc[1])
#print df['HC04_EST_VC123'].loc[0]
oceania_50000_74999 = float(df['HC04_EST_VC123'].loc[1])
#print df_asia['HC02_EST_VC123'].loc[0]
asian_50000_74999 = float(df_asia['HC02_EST_VC123'].loc[1])

#print df['HC01_EST_VC124'].loc[0]
tot_75000_up = float(df['HC01_EST_VC124'].loc[1])
#print df['HC02_EST_VC124'].loc[0]
africa_75000_up = float(df['HC02_EST_VC124'].loc[1])
#print df['HC03_EST_VC124'].loc[0]
northa_75000_up = float(df['HC03_EST_VC124'].loc[1])
#print df['HC04_EST_VC124'].loc[0]
oceania_75000_up = float(df['HC04_EST_VC124'].loc[1])
#print df_asia['HC02_EST_VC124'].loc[0]
asian_75000_up = float(df_asia['HC02_EST_VC124'].loc[1])

# %%
earn_1_9999 = [tot_1_9999, africa_1_9999, northa_1_9999, oceania_1_9999, asian_1_9999]
earn_10000_14999 = [tot_10000_14999, africa_10000_14999, northa_10000_14999, oceania_10000_14999, asian_10000_14999]
earn_15000_24999 = [tot_15000_24999, africa_15000_24999, northa_15000_24999, oceania_15000_24999, asian_15000_24999]
earn_25000_34999 = [tot_25000_34999, africa_25000_34999, northa_25000_34999, oceania_25000_34999, asian_25000_34999]
earn_35000_49999 = [tot_35000_49999, africa_35000_49999, northa_35000_49999, oceania_35000_49999, asian_35000_49999]
earn_50000_74999 = [tot_50000_74999, africa_50000_74999, northa_50000_74999, oceania_50000_74999, asian_50000_74999]
earn_75000_up = [tot_75000_up, africa_75000_up, northa_75000_up, oceania_75000_up, asian_75000_up]

X = np.arange(5)
width = 0.5
plt.figure(figsize=(15,15))
p1 = plt.bar(X,earn_1_9999, color = '#073B4C', width=width)
p2 = plt.bar(X,earn_10000_14999, color = '#87CEFA', bottom = [earn_1_9999[j] for j in range(len(earn_1_9999))], width=width)
p3 = plt.bar(X,earn_15000_24999, color='#9ACD32', bottom = [earn_1_9999[j] + earn_10000_14999[j] for j in range(len(earn_1_9999))], width=width)
p4 = plt.bar(X,earn_25000_34999, color='#F08080', bottom = [earn_1_9999[j] + earn_10000_14999[j] + earn_15000_24999[j] for j in range(len(earn_1_9999))], width=width)
p5 = plt.bar(X,earn_35000_49999, color='#FF7F50', bottom = [earn_1_9999[j] + earn_10000_14999[j] + earn_15000_24999[j] + earn_25000_34999[j] for j in range(len(earn_1_9999))], width=width)
p6 = plt.bar(X,earn_50000_74999, color='#ff5a1d', bottom = [earn_1_9999[j] + earn_10000_14999[j] + earn_15000_24999[j] + earn_25000_34999[j] + earn_35000_49999[j] for j in range(len(earn_1_9999))], width=width)
p7 = plt.bar(X,earn_75000_up, color='#ffcb1d', bottom = [earn_1_9999[j] + earn_10000_14999[j] + earn_15000_24999[j] + earn_25000_34999[j] + earn_35000_49999[j] + earn_50000_74999[j] for j in range(len(earn_1_9999))], width=width)
p8 = plt.xticks(X+width/2.,('Total Labor Force','African','North American','Oceanic','Asian'), fontsize=16)
plt.xlabel('Place of Origin',fontsize=16)
plt.ylabel('Percentage of Income Earners by Group', fontsize=16)
plt.title('Income Breakdown by Place of Origin', fontsize=16)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0], p7[0]), ('$1-9999 or less','$10000-14999','$15000-24999','$25000-34999','$35000-49999','$50000-74999','$75000 and up'), fontsize=12)
plt.show()

# %%
manage = [tot_manage, africa_manage, northa_manage, oceania_manage, asian_manage]
service = [tot_service, africa_service, northa_service, oceania_service, asian_service]
sales = [tot_sales, africa_sales, northa_sales, oceania_sales, asian_sales]
maintenance = [tot_maintenance, africa_maintenance, northa_maintenance, oceania_maintenance, asian_maintenance]
moving = [tot_moving, africa_moving, northa_moving, oceania_moving, asian_moving]

X = np.arange(5)
width = 0.1

plt.figure(figsize=(15,11))
p1 = plt.bar(X, manage, color = '#073B4C', width=width)
p2 = plt.bar([i+0.1 for i in X], service, color = '#87CEFA', width=width)
p3 = plt.bar([i+0.2 for i in X], sales, color='#9ACD32',width=width)
p4 = plt.bar([i+0.3 for i in X], maintenance, color='#F08080', width=width)
p5 = plt.bar([i+0.4 for i in X], moving, color='#FF7F50',  width=width)
p6 = plt.bar([i+0.5 for i in X], earn_1_9999, color='#FFFFFF', width=width)
p7 = plt.xticks(X+width/2.,('Overall Labor Force in US','African','North American','Oceanic','Asian'), fontsize=16)
plt.xlabel('Place of Origin', fontsize=16)
plt.ylabel('Percentage of Labor Force', fontsize=16)
plt.title('Labor Force by Place of Origin', fontsize=16)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0]), ('Management, business, science, arts', 'Service', 'Sales and office', 'Natural resources, construction, and maintenance', 'Production, transportation, and material moving'), fontsize=12)
plt.show()

# %%
earn_1_9999 = [tot_1_9999, africa_1_9999, northa_1_9999, oceania_1_9999, asian_1_9999]
earn_10000_14999 = [tot_10000_14999, africa_10000_14999, northa_10000_14999, oceania_10000_14999, asian_10000_14999]
earn_15000_24999 = [tot_15000_24999, africa_15000_24999, northa_15000_24999, oceania_15000_24999, asian_15000_24999]
earn_25000_34999 = [tot_25000_34999, africa_25000_34999, northa_25000_34999, oceania_25000_34999, asian_25000_34999]
earn_35000_49999 = [tot_35000_49999, africa_35000_49999, northa_35000_49999, oceania_35000_49999, asian_35000_49999]
earn_50000_74999 = [tot_50000_74999, africa_50000_74999, northa_50000_74999, oceania_50000_74999, asian_50000_74999]
earn_75000_up = [tot_75000_up, africa_75000_up, northa_75000_up, oceania_75000_up, asian_75000_up]

X = np.arange(5)
width = 0.1
plt.figure(figsize=(15,12))
p1 = plt.bar(X,earn_1_9999, color = '#073B4C', width=width)
p2 = plt.bar([i+0.1 for i in X],earn_10000_14999, color = '#87CEFA', width=width)
p3 = plt.bar([i+0.2 for i in X],earn_15000_24999, color='#9ACD32', width=width)
p4 = plt.bar([i+0.3 for i in X],earn_25000_34999, color='#F08080', width=width)
p5 = plt.bar([i+0.4 for i in X],earn_35000_49999, color='#FF7F50', width=width)
p6 = plt.bar([i+0.5 for i in X],earn_50000_74999, color='#ff5a1d', width=width)
p7 = plt.bar([i+0.6 for i in X],earn_75000_up, color='#ffcb1d', width=width)
p8 = plt.xticks(X+width/2.+0.3,('Total Labor Force','African','North American','Oceanic','Asian'), fontsize=16)
plt.xlabel('Place of Origin',fontsize=16)
plt.ylabel('Percentage of Income Earners by Group', fontsize=16)
plt.title('Income Breakdown by Place of Origin', fontsize=16)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0], p6[0], p7[0]), ('$1-9999 or less','$10000-14999','$15000-24999','$25000-34999','$35000-49999','$50000-74999','$75000 and up'), fontsize=12)
plt.show()
